# %% [markdown]
# # Linear Algebra for Machine Learning 📐
#
# Linear algebra is used everywhere in ML:
# neural networks, regression, PCA, deep learning.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %%
import numpy as np

# %% [markdown]
# ## Scalars, Vectors, and Matrices

# %%
scalar = 5
vector = np.array([1, 2, 3])
matrix = np.array([[1, 2], [3, 4]])

print("Scalar:", scalar)
print("Vector:", vector)
print("Matrix:\n", matrix)
# Out:
# Scalar: 5
# Vector: [1 2 3]
# Matrix:
#  [[1 2]
#  [3 4]]

# %% [markdown]
# ## Vector Operations

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

print("Addition:", v1 + v2)
print("Dot Product:", np.dot(v1, v2))
# Out:
# Addition: [5 7 9]
# Dot Product: 32

# %% [markdown]
# ## Matrix Operations

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

print("Matrix Multiplication:\n", np.dot(A, B))
# Out:
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]

# %% [markdown]
# ## Transpose

# %%
print(A.T)
# Out:
# [[1 3]
#  [2 4]]

# %% [markdown]
# ## Determinant

# %%
print("Determinant:", np.linalg.det(A))
# Out:
# Determinant: -2.0000000000000004

# %% [markdown]
# ## Inverse

# %%
print("Inverse:\n", np.linalg.inv(A))
# Out:
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# ## Why Linear Algebra is Important?

# %% [markdown]
# - Neural networks
# - Linear regression
# - Image processing
# - Deep learning

# %% [markdown]
# ## 🧪 Practice
#
# 1. Create your own matrix
# 2. Find determinant
# 3. Find inverse

# %% [markdown]
# ## ✅ Summary
#
# You learned:
# - Vectors
# - Matrices
# - Dot product
# - Determinant
# - Inverse
#
# ➡️ Next: **Calculus**
