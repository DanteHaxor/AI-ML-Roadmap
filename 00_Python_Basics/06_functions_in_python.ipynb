# %% [markdown]
# # Functions in Python 🧩
#
# Functions are reusable blocks of code that perform a specific task.
# They help make programs modular, readable, and maintainable.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## Why Use Functions?
#
# - Avoid code repetition
# - Improve readability
# - Easier debugging and testing
# - Widely used in AI/ML pipelines

# %% [markdown]
# ## Defining a Function
#
# A function is defined using the `def` keyword.

# %%
def greet():
    print("Hello, welcome to Python!")

greet()

# %% [markdown]
# ## Function with Parameters
#
# Parameters allow passing data to functions.

# %%
def greet_user(name):
    print("Hello", name)

greet_user("Abhay")

# %% [markdown]
# ## Function with Return Value
#
# The `return` statement sends a value back to the caller.

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print("Sum:", result)

# %% [markdown]
# ## Types of Functions
#
# 1. Built-in Functions (print, len, type)
# 2. User-defined Functions

# %%
numbers = [1, 2, 3, 4, 5]
print(len(numbers))
print(type(numbers))

# %% [markdown]
# ## Default Parameters
#
# Default values are used when no argument is passed.

# %%
def power(base, exp=2):
    return base ** exp

print(power(5))
print(power(5, 3))

# %% [markdown]
# ## Keyword Arguments
#
# Arguments can be passed using parameter names.

# %%
def student_info(name, age):
    print("Name:", name)
    print("Age:", age)

student_info(age=20, name="Abhay")

# %% [markdown]
# ## Lambda Functions
#
# Lambda functions are **anonymous functions** written in one line.

# %%
square = lambda x: x * x
print(square(5))

# %% [markdown]
# ## Lambda with Multiple Arguments

# %%
add = lambda a, b: a + b
print(add(10, 20))

# %% [markdown]
# ## Functions vs Lambda
#
# | Function | Lambda |
# |--------|--------|
# | Multi-line | Single-line |
# | Named | Anonymous |
# | Complex logic | Simple expressions |

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# - Forgetting to call the function
# - Missing return statement
# - Confusing print with return

# %% [markdown]
# ## 🧪 Practice Problems
#
# 1. Write a function to check if a number is even or odd.
# 2. Write a function that returns factorial of a number.
# 3. Write a lambda function to find the maximum of two numbers.
# 4. Create a function that takes a list and returns its sum.

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, you learned:
# - What functions are
# - Parameters and return values
# - Types of functions
# - Lambda functions
#
# ➡️ Next: **Strings in Python**
