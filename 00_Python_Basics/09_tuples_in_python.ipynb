# %% [markdown]
# # Tuples in Python 📦
#
# Tuples are used to store multiple items in a single variable.
# They are similar to lists but **immutable**.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## What is a Tuple?
#
# A tuple is:
# - Ordered
# - Immutable (cannot be changed)
# - Allows duplicate values
# - Can store different data types

# %%
numbers = (1, 2, 3, 4)
names = ("Abhay", "Rahul", "Aman")
mixed = (1, "Python", 3.5, True)

print(numbers)
print(names)
print(mixed)

# %% [markdown]
# ## Single Element Tuple
#
# A tuple with one element **must have a comma**.

# %%
single = (10,)
print(type(single))

not_tuple = (10)
print(type(not_tuple))

# %% [markdown]
# ## Accessing Tuple Elements
#
# Tuple indexing and slicing work similar to lists.

# %%
t = (10, 20, 30, 40, 50)

print(t[0])
print(t[-1])
print(t[1:4])

# %% [markdown]
# ## Tuple Immutability
#
# Tuples cannot be modified after creation.

# %%
t = (1, 2, 3)

# This will cause an error
# t[0] = 10

# %% [markdown]
# ## Tuple Methods
#
# Tuples have only two built-in methods:
# | Method    | Description       |
# | --------- | ----------------- |
# | `count()` | Count occurrences |
# | `index()` | Find index        |

# %%
t = (1, 2, 3, 2, 4, 2)

print(t.count(2))
print(t.index(3))

# %% [markdown]
# ## Tuple Packing and Unpacking

# %%
# Packing
student = ("Abhay", 20, "AI/ML")

# Unpacking
name, age, course = student

print(name)
print(age)
print(course)

# %% [markdown]
# ## Using Tuples with Loops

# %%
colors = ("red", "green", "blue")

for color in colors:
    print(color)

# %% [markdown]
# ## Tuple vs List
# | Tuple       | List         |
# | ----------- | ------------ |
# | Immutable   | Mutable      |
# | Faster      | Slower       |
# | Less memory | More memory  |
# | Fixed data  | Dynamic data |

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# - Forgetting comma in single-element tuple
# - Trying to modify tuple elements

# %% [markdown]
# ## 🧪 Practice Problems
#
# 1. Create a tuple of numbers and find its sum.
# 2. Convert a tuple into a list and modify it.
# 3. Unpack a tuple of student details.
# 4. Count how many times a value appears in a tuple.

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, you learned:
# - Creating tuples
# - Indexing and slicing
# - Tuple immutability
# - Tuple methods
# - Packing and unpacking
#
# ➡️ Next: **Dictionary in Python**
