# %% [markdown]
# # Dictionary in Python 🗂️
#
# Dictionaries are used to store data in **key-value pairs**.
# They are very important in data handling and real-world applications.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## What is a Dictionary?
#
# A dictionary:
# - Stores data as **key : value**
# - Is unordered (in older versions)
# - Is mutable
# - Does not allow duplicate keys

# %%
student = {
    "name": "Abhay",
    "age": 20,
    "course": "AI/ML"
}

print(student)
# Out:
# {'name': 'Abhay', 'age': 20, 'course': 'AI/ML'}

# %% [markdown]
# ## Accessing Dictionary Values
#
# Values are accessed using keys.

# %%
print(student["name"])
print(student.get("age"))
# Out:
# Abhay
# 20

# %% [markdown]
# ## Modifying Dictionary
#
# Dictionaries are mutable.
# You can add or update values.

# %%
student["age"] = 21
student["city"] = "Delhi"

print(student)
# Out:
# {'name': 'Abhay', 'age': 21, 'course': 'AI/ML', 'city': 'Delhi'}

# %% [markdown]
# ## Removing Elements from Dictionary

# %%
student.pop("city")
del student["course"]

print(student)
# Out:
# {'name': 'Abhay', 'age': 21}

# %% [markdown]
# ## Common Dictionary Methods
# | Method     | Description         |
# | ---------- | ------------------- |
# | `keys()`   | Get all keys        |
# | `values()` | Get all values      |
# | `items()`  | Get key-value pairs |
# | `update()` | Update dictionary   |
# | `clear()`  | Remove all items    |

# %%
student = {"name": "Abhay", "age": 21}

print(student.keys())
print(student.values())
print(student.items())

student.update({"age": 22})
print(student)
# Out:
# dict_keys(['name', 'age'])
# dict_values(['Abhay', 21])
# dict_items([('name', 'Abhay'), ('age', 21)])
# {'name': 'Abhay', 'age': 22}

# %% [markdown]
# ## Looping Through a Dictionary

# %%
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Abhay
# age : 22

# %% [markdown]
# ## Nested Dictionary
#
# A dictionary inside another dictionary.

# %%
students = {
    "student1": {"name": "Abhay", "age": 20},
    "student2": {"name": "Rahul", "age": 21}
}

print(students["student1"]["name"])
# Out:
# Abhay

# %% [markdown]
# ## Dictionary Comprehension
#
# Create dictionaries using a concise syntax.

# %%
squares = {x: x**2 for x in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# - Using mutable keys (like lists)
# - Accessing non-existing keys directly
# - Confusing `[]` and `get()`

# %% [markdown]
# ## 🧪 Practice Problems
#
# 1. Create a dictionary of 5 students and their marks.
# 2. Find the student with highest marks.
# 3. Count frequency of characters in a string using dictionary.
# 4. Merge two dictionaries.

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, you learned:
# - Creating dictionaries
# - Accessing and modifying data
# - Dictionary methods
# - Looping and nested dictionaries
# - Dictionary comprehension
#
# ➡️ Next: **Sets in Python**
