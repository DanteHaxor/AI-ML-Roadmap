# %% [markdown]
# # Operators in Python 🧮
#
# Operators are used to perform operations on variables and values.
# They are one of the most important building blocks of Python programming.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## Types of Operators in Python
#
# Python supports the following types of operators:
#
# 1. Arithmetic Operators
# 2. Relational (Comparison) Operators
# 3. Assignment Operators
# 4. Logical Operators
# 5. Operator Precedence

# %% [markdown]
# ## 1️⃣ Arithmetic Operators
#
# Arithmetic operators are used to perform mathematical operations.
# | Operator | Description    |
# | -------- | -------------- |
# | `+`      | Addition       |
# | `-`      | Subtraction    |
# | `*`      | Multiplication |
# | `/`      | Division       |
# | `//`     | Floor Division |
# | `%`      | Modulus        |
# | `**`     | Exponentiation |

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Power:", a ** b)

# %% [markdown]
# ## 2️⃣ Relational (Comparison) Operators
#
# Relational operators are used to compare two values.
# The result is always **True** or **False**.
# | Operator | Description              |
# | -------- | ------------------------ |
# | `==`     | Equal to                 |
# | `!=`     | Not equal to             |
# | `>`      | Greater than             |
# | `<`      | Less than                |
# | `>=`     | Greater than or equal to |
# | `<=`     | Less than or equal to    |

# %%
x = 5
y = 10

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)

# %% [markdown]
# ## 3️⃣ Assignment Operators
#
# Assignment operators are used to assign values to variables.
# | Operator | Example | Meaning   |
# | -------- | ------- | --------- |
# | `=`      | x = 5   | Assign    |
# | `+=`     | x += 2  | x = x + 2 |
# | `-=`     | x -= 2  | x = x - 2 |
# | `*=`     | x *= 2  | x = x * 2 |
# | `/=`     | x /= 2  | x = x / 2 |

# %%
x = 10

x += 5
print(x)

x -= 3
print(x)

x *= 2
print(x)

x /= 4
print(x)

# %% [markdown]
# ## 4️⃣ Logical Operators
#
# Logical operators are used to combine conditional statements.
# | Operator | Description                            |
# | -------- | -------------------------------------- |
# | `and`    | True if both conditions are True       |
# | `or`     | True if at least one condition is True |
# | `not`    | Reverses the result                    |

# %%
a = 5
b = 10

print(a > 3 and b > 5)
print(a > 6 or b > 5)
print(not(a > 3))

# %% [markdown]
# ## 5️⃣ Operator Precedence
#
# Operator precedence determines the **order** in which operations are performed.
#
# **Highest → Lowest priority**
# | Order | Operator               |
# | ----- | ---------------------- |
# | 1     | `()`                   |
# | 2     | `**`                   |
# | 3     | `*, /, //, %`          |
# | 4     | `+, -`                 |
# | 5     | `==, !=, >, <, >=, <=` |
# | 6     | `and`                  |
# | 7     | `or`                   |

# %%
result = 10 + 2 * 3
print(result)  # Multiplication happens first

result = (10 + 2) * 3
print(result)  # Parentheses change precedence

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# - Confusing `=` with `==`
# - Forgetting operator precedence
# - Using logical operators without proper conditions

# %% [markdown]
# ## 🧪 Practice Problems
#
# 1. Take two numbers from the user and perform all arithmetic operations.
# 2. Check whether a number is greater than 50 and even.
# 3. Predict the output before running:
# 10 + 5 * 2 ** 2
# 4. Write a condition using `and`, `or`, and `not`.

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, you learned:
# - Arithmetic operators
# - Relational operators
# - Assignment operators
# - Logical operators
# - Operator precedence
#
# ➡️ Next: **Type Conversion & User Input**
