# %% [markdown]
# # OOPS Principles in Python 🧠
#
# Object-Oriented Programming is built on four main principles:
# Encapsulation, Inheritance, Polymorphism, and Abstraction.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## Four Core OOPS Principles
#
# 1. Encapsulation
# 2. Inheritance
# 3. Polymorphism
# 4. Abstraction

# %% [markdown]
# ## 1️⃣ Encapsulation
#
# Encapsulation means **binding data and methods together**
# and restricting direct access to data.

# %%
class Account:
    def __init__(self, balance):
        self.__balance = balance  # private variable

    def show_balance(self):
        print("Balance:", self.__balance)

acc = Account(5000)
acc.show_balance()

# acc.__balance  # This will cause an error
# Out:
# Balance: 5000

# %% [markdown]
# ## 2️⃣ Inheritance
#
# Inheritance allows one class to acquire properties of another class.

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

d = Dog()
d.speak()
d.bark()
# Out:
# Animal makes a sound
# Dog barks

# %% [markdown]
# ## Types of Inheritance
#
# - Single
# - Multiple
# - Multilevel
# - Hierarchical
# - Hybrid

# %%
class Vehicle:
    def start(self):
        print("Vehicle started")

class Car(Vehicle):
    def drive(self):
        print("Car is driving")

class ElectricCar(Car):
    def charge(self):
        print("Car is charging")

ec = ElectricCar()
ec.start()
ec.drive()
ec.charge()
# Out:
# Vehicle started
# Car is driving
# Car is charging

# %% [markdown]
# ## Multiple Inheritance
#
# A class can inherit from more than one parent class.

# %%
class Camera:
    def feature(self):
        print("Camera feature")

class GPS:
    def feature(self):
        print("GPS feature")

class Smartphone(Camera, GPS):
    pass

phone = Smartphone()
phone.feature()
# Out:
# Camera feature

# %% [markdown]
# ## 3️⃣ Polymorphism
#
# Polymorphism means **many forms**.
# The same method name behaves differently.

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

b = Bird()
p = Penguin()

b.fly()
p.fly()
# Out:
# Bird can fly
# Penguin cannot fly

# %% [markdown]
# ## 4️⃣ Abstraction
#
# Abstraction hides implementation details
# and shows only essential features.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Square(Shape):
    def area(self):
        return 4 * 4

s = Square()
print(s.area())
# Out:
# 16

# %% [markdown]
# ## Why Use Abstraction?
#
# - Improves code clarity
# - Enforces method implementation
# - Helps in large-scale projects

# %% [markdown]
# ## Real-Life Analogy
#
# Think of a TV remote:
# - You press buttons (interface)
# - You don't know internal wiring (implementation)

# %% [markdown]
# ## ⚠️ Common Mistakes
#
# - Forgetting to use `super()` when needed
# - Misunderstanding method overriding
# - Trying to create object of abstract class

# %% [markdown]
# ## 🧪 Practice Problems
#
# 1. Create a base class `Employee` and derived class `Manager`.
# 2. Demonstrate method overriding.
# 3. Create an abstract class `Vehicle`.
# 4. Implement multiple inheritance example.

# %% [markdown]
# ## ✅ Summary
#
# In this notebook, you learned:
# - Encapsulation
# - Inheritance and its types
# - Polymorphism
# - Abstraction
#
# ➡️ Next: **File Handling in Python**
