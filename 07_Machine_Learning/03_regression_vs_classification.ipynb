# %% [markdown]
# # Regression vs Classification 🎯
#
# Regression and Classification are the two core problem types
# in supervised machine learning.
#
# Understanding the difference is critical before learning algorithms.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## What is Regression?
#
# Regression is used when the **output variable is continuous**.
# The model predicts a numerical value.

# %% [markdown]
# ### Examples of Regression
#
# - Predict house prices
# - Predict salary based on experience
# - Predict temperature

# %% [markdown]
# ## What is Classification?
#
# Classification is used when the **output variable is categorical**.
# The model predicts a class or label.

# %% [markdown]
# ### Examples of Classification
#
# - Spam vs Not Spam
# - Disease: Yes / No
# - Fraud vs Non-Fraud

# %% [markdown]
# ## Key Differences

# %% [markdown]
# | Feature | Regression | Classification |
# |-------|------------|----------------|
# | Output | Continuous | Categorical |
# | Example | Price | Spam / Not Spam |
# | Metrics | MSE, RMSE | Accuracy, Precision |

# %% [markdown]
# ## Visual Intuition

# %% [markdown]
# - Regression fits a **line/curve**
# - Classification finds a **decision boundary**

# %% [markdown]
# ## Algorithms Used

# %% [markdown]
# ### Regression Algorithms
# - Linear Regression
# - Ridge, Lasso
# - Polynomial Regression
#
# ### Classification Algorithms
# - Logistic Regression
# - Naive Bayes
# - KNN
# - Decision Tree

# %% [markdown]
# ## How to Choose Between Them?

# %% [markdown]
# - If output is numeric → Regression
# - If output is label → Classification

# %% [markdown]
# ## Why This Matters?

# %% [markdown]
# Choosing the wrong type leads to:
# - Poor performance
# - Wrong evaluation metrics
# - Invalid predictions

# %% [markdown]
# ## ✅ Summary
#
# You learned:
# - What regression is
# - What classification is
# - Key differences
# - When to use each
#
# ➡️ Next: **Introduction to scikit-learn**
