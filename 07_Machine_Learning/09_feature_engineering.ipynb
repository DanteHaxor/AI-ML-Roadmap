# %% [markdown]
# # Feature Engineering 🧠🛠️
#
# Feature Engineering is the process of creating, transforming,
# and selecting features to improve ML model performance.
#
# 📌 Part of: **AI/ML Roadmap – Beginner to Advanced**

# %% [markdown]
# ## Why Feature Engineering Matters?
#
# Good features can:
# - Improve accuracy
# - Reduce overfitting
# - Make models simpler and faster

# %% [markdown]
# ## Common Feature Engineering Techniques

# %% [markdown]
# - Feature creation
# - Feature transformation
# - Feature selection
# - Encoding categorical variables

# %% [markdown]
# ## Example Dataset

# %%
import pandas as pd

df = pd.DataFrame({
    "Length": [10, 15, 20, 25],
    "Width": [5, 7, 10, 12],
    "Price": [100, 150, 200, 250]
})

print(df)

# %% [markdown]
# ## Feature Creation

# %%
# Create new feature: Area
df["Area"] = df["Length"] * df["Width"]
print(df)

# %% [markdown]
# ## Feature Transformation

# %%
import numpy as np

df["Log_Price"] = np.log(df["Price"])
print(df)

# %% [markdown]
# ## Feature Selection

# %%
# Drop less useful feature
df_selected = df.drop(columns=["Width"])
print(df_selected)

# %% [markdown]
# ## Domain Knowledge Matters

# %% [markdown]
# Feature engineering depends heavily on:
# - Problem understanding
# - Data behavior
# - Business context

# %% [markdown]
# ## Why Feature Engineering is Hard?

# %% [markdown]
# - No fixed rules
# - Problem-specific
# - Requires experimentation

# %% [markdown]
# ## 🧪 Practice
#
# 1. Create a new feature
# 2. Apply transformation
# 3. Drop a column

# %% [markdown]
# ## ✅ Summary
#
# You learned:
# - What feature engineering is
# - Feature creation
# - Feature transformation
# - Feature selection
#
# ➡️ Next: **Dummy Variables & Encoding**
